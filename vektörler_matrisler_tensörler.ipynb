# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ![svt2.png](attachment:svt2.png)

# %% [markdown]
# ![svt.jpg](attachment:svt.jpg)

# %%
skaler=np.array(7)#scalar
skaler
# Out:
# array(7)

# %%
#boyutu : ndim

# %%
skaler.ndim #scalar'ın boyutu 0
# Out:
# 0

# %%
vektor=np.array([7,14,21])
vektor
# Out:
# array([ 7, 14, 21])

# %%
vektor.ndim #vektör'ün boyutu 1
# Out:
# 1

# %%
matris=np.array([[4,5,6],
                [7,8,9],
                [4,5,6]])
matris
# Out:
# array([[4, 5, 6],
#        [7, 8, 9],
#        [4, 5, 6]])

# %%
matris.ndim #satır ve sütunlardan oluştuğu için artık bu iki boyutlu
# Out:
# 2

# %%
#İki boyuttan büyük olduğu zaman buna TENSÖR diyeceğiz.
#Tensörlerin satırları, sütunları ve derilikleri olur.

# %%
tensor=np.array([[[4,5,6],[4,5,6]],
                [[7,8,9],[7,8,9]],
                [[1,2,3],[1,2,3]]])
tensor
# Out:
# array([[[4, 5, 6],
#         [4, 5, 6]],
#
#        [[7, 8, 9],
#         [7, 8, 9]],
#
#        [[1, 2, 3],
#         [1, 2, 3]]])

# %%
#3 tane matrisi arka arkaya koymuşuz gibi düşünebiliriz
tensor.ndim

# %%
#görüntü veri seti çekelim
from keras.datasets import mnist
(train_images, train_labels), (test_images, testlabels)=mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-101103e55f82> in <module>
#       1 #görüntü veri seti çekelim
# ----> 2 from keras.datasets import mnist
#       3 (train_images, train_labels), (test_images, testlabels)=mnist.load_data()
#
# ModuleNotFoundError: No module named 'keras'

# %%
print(train_images.ndim)

# %%
import random

# %%
random.seed(1)
print(random.random())
# Out:
# 0.13436424411240122

# %%
random.seed(10)
print(random.random())
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.5714025946899135
# 0.4288890546751146
# 0.5780913011344704
# 0.20609823213950174
